# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS batch_external_location
  URL 's3://data-batch-dbr/'
  WITH (STORAGE CREDENTIAL credential_dbr);

CREATE EXTERNAL LOCATION IF NOT EXISTS streaming_external_location
  URL 's3://data-streaming-dbr/'
  WITH (STORAGE CREDENTIAL credential_dbr);

SHOW EXTERNAL LOCATIONS;

# %%
# %sql

CREATE CATALOG IF NOT EXISTS  retail_rocket;

USE CATALOG retail_rocket;

-- Ingestion layer: doc raw data tu S3
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE SCHEMA IF NOT EXISTS serving;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS retail_rocket.bronze.checkpoints;
CREATE VOLUME IF NOT EXISTS retail_rocket.silver.checkpoints;

SHOW VOLUMES IN retail_rocket.bronze;
-- SHOW VOLUMES IN retail_rocket.silver;

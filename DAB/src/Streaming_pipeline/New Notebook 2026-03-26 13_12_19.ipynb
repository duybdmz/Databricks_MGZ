# %%
# %sql
select * from retail_rocket.bronze.ingest_events

# %%
# %sql
select*
from retail_rocket.silver.transform_events
limit 10;

# %%
# %sql
select * from retail_rocket.gold.speed_view_item_performance

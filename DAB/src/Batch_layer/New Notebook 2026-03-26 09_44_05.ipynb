# %%
# %sql
select*
from retail_rocket.bronze.bronze_category_tree 
limit 10 ;

# %%
# %sql
select * from retail_rocket.bronze.bronze_item_properties

# %%
# %sql
DESCRIBE DETAIL  retail_rocket.bronze.bronze_category_tree

# %%
# %sql
SELECT * FROM read_state_metadata('/checkpoint/path');
\

# %%
# %sql DESCRIBE HISTORY retail_rocket.bronze.bronze_category_tree

# %%
# %fs ls 's3://dbstorage-prod-i7efw/uc/db5bdb98-96fe-4b4d-bdf9-14c56ba001e7/6e312fe9-f61c-422a-bda3-d62509db6c81/__unitystorage/catalogs/798ad4a1-2cef-4cbe-981e-944d81d75145/tables/3d099d1a-f400-415e-ba1c-960f0b325ee6'

# %%
# %sql
select * from retail_rocket.silver.silver_item_properties
limit 100 ;

# %%
# %sql 
select * from retail_rocket.gold.gold_dim_product
